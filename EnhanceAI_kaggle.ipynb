# %% [markdown]
# <a href="https://www.kaggle.com/code/meormuhdnabil/enhanceai?scriptVersionId=186408211" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !git clone https://github.com/WhosMeor/EnhanceAI
# Out:
# Cloning into 'EnhanceAI'...
# remote: Enumerating objects: 185, done.
# remote: Counting objects: 100% (185/185), done.
# remote: Compressing objects: 100% (178/178), done.
# remote: Total 185 (delta 70), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (185/185), 22.98 MiB | 15.86 MiB/s, done.
# Resolving deltas: 100% (70/70), done.

# %%
# %cd EnhanceAI
# !pip install -r requirements.txt
# Out:
# /kaggle/working/EnhanceAI
# Collecting facexlib>=0.2.5 (from -r requirements.txt (line 1))
#   Downloading facexlib-0.3.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (4.10.0.82)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (9.5.0)
# Requirement already satisfied: torch>=1.7 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (2.1.2)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (0.16.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (4.66.4)
# Collecting streamlit (from -r requirements.txt (line 8))
#   Downloading streamlit-1.36.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting new-gfpgan==1.0.1 (from -r requirements.txt (line 10))
#   Downloading new_gfpgan-1.0.1-py3-none-any.whl.metadata (13 kB)
# Collecting MY-basicsr==1.4.2 (from -r requirements.txt (line 11))
#   Downloading my_basicsr-1.4.2-py3-none-any.whl.metadata (11 kB)
# Collecting pyrebase4 (from -r requirements.txt (line 12))
#   Downloading Pyrebase4-4.8.0-py3-none-any.whl.metadata (662 bytes)
# Collecting streamlit-extras (from -r requirements.txt (line 13))
#   Downloading streamlit_extras-0.4.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting streamlit-image-comparison (from -r requirements.txt (line 14))
#   Downloading streamlit_image_comparison-0.0.4-py3-none-any.whl.metadata (4.2 kB)
# Collecting streamlit-option-menu (from -r requirements.txt (line 15))
#   Downloading streamlit_option_menu-0.3.13-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyngrok (from -r requirements.txt (line 16))
#   Downloading pyngrok-7.1.6-py3-none-any.whl.metadata (7.4 kB)
# Collecting new-basicsr>=1.0.0 (from new-gfpgan==1.0.1->-r requirements.txt (line 10))
#   Downloading new_basicsr-1.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting lmdb (from new-gfpgan==1.0.1->-r requirements.txt (line 10))
#   Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from new-gfpgan==1.0.1->-r requirements.txt (line 10)) (6.0.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from new-gfpgan==1.0.1->-r requirements.txt (line 10)) (1.11.4)
# Collecting tb-nightly (from new-gfpgan==1.0.1->-r requirements.txt (line 10))
#   Downloading tb_nightly-2.18.0a20240701-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: yapf in /opt/conda/lib/python3.10/site-packages (from new-gfpgan==1.0.1->-r requirements.txt (line 10)) (0.40.2)
# Collecting addict (from MY-basicsr==1.4.2->-r requirements.txt (line 11))
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: future in /opt/conda/lib/python3.10/site-packages (from MY-basicsr==1.4.2->-r requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from MY-basicsr==1.4.2->-r requirements.txt (line 11)) (2.32.3)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.10/site-packages (from MY-basicsr==1.4.2->-r requirements.txt (line 11)) (0.22.0)
# Collecting filterpy (from facexlib>=0.2.5->-r requirements.txt (line 1))
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 7.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numba in /opt/conda/lib/python3.10/site-packages (from facexlib>=0.2.5->-r requirements.txt (line 1)) (0.58.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.7->-r requirements.txt (line 5)) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.7->-r requirements.txt (line 5)) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.7->-r requirements.txt (line 5)) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.7->-r requirements.txt (line 5)) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.7->-r requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.7->-r requirements.txt (line 5)) (2024.3.1)
# Requirement already satisfied: altair<6,>=4.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 8)) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 8)) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 8)) (4.2.4)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 8)) (8.1.7)
# Requirement already satisfied: packaging<25,>=20 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 8)) (21.3)
# Requirement already satisfied: pandas<3,>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 8)) (2.2.1)
# Requirement already satisfied: protobuf<6,>=3.20 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 8)) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 8)) (14.0.2)
# Requirement already satisfied: rich<14,>=10.14.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 8)) (13.7.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 8)) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 8)) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 8)) (3.1.41)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->-r requirements.txt (line 8))
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 8)) (6.3.3)
# Collecting watchdog<5,>=2.1.5 (from streamlit->-r requirements.txt (line 8))
#   Downloading watchdog-4.0.1-py3-none-manylinux2014_x86_64.whl.metadata (37 kB)
# Requirement already satisfied: requests-toolbelt<1.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from pyrebase4->-r requirements.txt (line 12)) (0.10.1)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from pyrebase4->-r requirements.txt (line 12)) (1.26.18)
# Collecting gcloud>=0.18.3 (from pyrebase4->-r requirements.txt (line 12))
#   Downloading gcloud-0.18.3.tar.gz (454 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.4/454.4 kB 24.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: oauth2client>=4.1.2 in /opt/conda/lib/python3.10/site-packages (from pyrebase4->-r requirements.txt (line 12)) (4.1.3)
# Collecting python-jwt>=2.0.1 (from pyrebase4->-r requirements.txt (line 12))
#   Downloading python_jwt-4.1.0-py2.py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pycryptodome>=3.6.4 in /opt/conda/lib/python3.10/site-packages (from pyrebase4->-r requirements.txt (line 12)) (3.20.0)
# Requirement already satisfied: entrypoints>=0.4 in /opt/conda/lib/python3.10/site-packages (from streamlit-extras->-r requirements.txt (line 13)) (0.4)
# Collecting htbuilder>=0.6.2 (from streamlit-extras->-r requirements.txt (line 13))
#   Downloading htbuilder-0.6.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting markdownlit>=0.0.5 (from streamlit-extras->-r requirements.txt (line 13))
#   Downloading markdownlit-0.0.7-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: prometheus-client>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from streamlit-extras->-r requirements.txt (line 13)) (0.19.0)
# Collecting st-annotated-text>=3.0.0 (from streamlit-extras->-r requirements.txt (line 13))
#   Downloading st_annotated_text-4.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting st-theme>=1.0.1 (from streamlit-extras->-r requirements.txt (line 13))
#   Downloading st_theme-1.2.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting streamlit-camera-input-live>=0.2.0 (from streamlit-extras->-r requirements.txt (line 13))
#   Downloading streamlit_camera_input_live-0.2.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting streamlit-card>=0.0.4 (from streamlit-extras->-r requirements.txt (line 13))
#   Downloading streamlit_card-1.0.2-py3-none-any.whl.metadata (4.0 kB)
# Collecting streamlit-embedcode>=0.1.2 (from streamlit-extras->-r requirements.txt (line 13))
#   Downloading streamlit_embedcode-0.1.2-py3-none-any.whl.metadata (414 bytes)
# Collecting streamlit-faker>=0.0.2 (from streamlit-extras->-r requirements.txt (line 13))
#   Downloading streamlit_faker-0.0.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting streamlit-image-coordinates<0.2.0,>=0.1.1 (from streamlit-extras->-r requirements.txt (line 13))
#   Downloading streamlit_image_coordinates-0.1.9-py3-none-any.whl.metadata (2.0 kB)
# Collecting streamlit-keyup>=0.1.9 (from streamlit-extras->-r requirements.txt (line 13))
#   Downloading streamlit_keyup-0.2.4-py3-none-any.whl.metadata (2.0 kB)
# Collecting streamlit-toggle-switch>=1.0.2 (from streamlit-extras->-r requirements.txt (line 13))
#   Downloading streamlit_toggle_switch-1.0.2-py3-none-any.whl.metadata (395 bytes)
# Collecting streamlit-vertical-slider>=2.5.5 (from streamlit-extras->-r requirements.txt (line 13))
#   Downloading streamlit_vertical_slider-2.5.5-py3-none-any.whl.metadata (2.2 kB)
# Collecting validators>=0.20.0 (from streamlit-extras->-r requirements.txt (line 13))
#   Downloading validators-0.29.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 8)) (4.20.0)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: httplib2>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from gcloud>=0.18.3->pyrebase4->-r requirements.txt (line 12)) (0.21.0)
# Requirement already satisfied: googleapis-common-protos in /opt/conda/lib/python3.10/site-packages (from gcloud>=0.18.3->pyrebase4->-r requirements.txt (line 12)) (1.62.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from gcloud>=0.18.3->pyrebase4->-r requirements.txt (line 12)) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 8)) (4.0.11)
# Requirement already satisfied: more-itertools in /opt/conda/lib/python3.10/site-packages (from htbuilder>=0.6.2->streamlit-extras->-r requirements.txt (line 13)) (10.2.0)
# Requirement already satisfied: markdown in /opt/conda/lib/python3.10/site-packages (from markdownlit>=0.0.5->streamlit-extras->-r requirements.txt (line 13)) (3.5.2)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from markdownlit>=0.0.5->streamlit-extras->-r requirements.txt (line 13)) (5.2.2)
# Collecting favicon (from markdownlit>=0.0.5->streamlit-extras->-r requirements.txt (line 13))
#   Downloading favicon-0.7.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Collecting pymdown-extensions (from markdownlit>=0.0.5->streamlit-extras->-r requirements.txt (line 13))
#   Downloading pymdown_extensions-10.8.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: pyasn1>=0.1.7 in /opt/conda/lib/python3.10/site-packages (from oauth2client>=4.1.2->pyrebase4->-r requirements.txt (line 12)) (0.5.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /opt/conda/lib/python3.10/site-packages (from oauth2client>=4.1.2->pyrebase4->-r requirements.txt (line 12)) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from oauth2client>=4.1.2->pyrebase4->-r requirements.txt (line 12)) (4.9)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging<25,>=20->streamlit->-r requirements.txt (line 8)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas<3,>=1.3.0->streamlit->-r requirements.txt (line 8)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3,>=1.3.0->streamlit->-r requirements.txt (line 8)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas<3,>=1.3.0->streamlit->-r requirements.txt (line 8)) (2023.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.7->-r requirements.txt (line 5)) (2.1.3)
# Collecting jwcrypto>=1.4.2 (from python-jwt>=2.0.1->pyrebase4->-r requirements.txt (line 12))
#   Downloading jwcrypto-1.5.6-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->MY-basicsr==1.4.2->-r requirements.txt (line 11)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->MY-basicsr==1.4.2->-r requirements.txt (line 11)) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->MY-basicsr==1.4.2->-r requirements.txt (line 11)) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 8)) (2.17.2)
# Collecting faker (from streamlit-faker>=0.0.2->streamlit-extras->-r requirements.txt (line 13))
#   Downloading Faker-26.0.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from streamlit-faker>=0.0.2->streamlit-extras->-r requirements.txt (line 13)) (3.7.5)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba->facexlib>=0.2.5->-r requirements.txt (line 1)) (0.41.1)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image->MY-basicsr==1.4.2->-r requirements.txt (line 11)) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image->MY-basicsr==1.4.2->-r requirements.txt (line 11)) (2023.12.9)
# Requirement already satisfied: lazy_loader>=0.3 in /opt/conda/lib/python3.10/site-packages (from scikit-image->MY-basicsr==1.4.2->-r requirements.txt (line 11)) (0.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.7->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tb-nightly->new-gfpgan==1.0.1->-r requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tb-nightly->new-gfpgan==1.0.1->-r requirements.txt (line 10)) (1.59.3)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.10/site-packages (from tb-nightly->new-gfpgan==1.0.1->-r requirements.txt (line 10)) (69.0.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tb-nightly->new-gfpgan==1.0.1->-r requirements.txt (line 10)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tb-nightly->new-gfpgan==1.0.1->-r requirements.txt (line 10)) (3.0.3)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /opt/conda/lib/python3.10/site-packages (from yapf->new-gfpgan==1.0.1->-r requirements.txt (line 10)) (6.11.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /opt/conda/lib/python3.10/site-packages (from yapf->new-gfpgan==1.0.1->-r requirements.txt (line 10)) (3.11.0)
# Requirement already satisfied: tomli>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from yapf->new-gfpgan==1.0.1->-r requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 8)) (5.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=6.6.0->yapf->new-gfpgan==1.0.1->-r requirements.txt (line 10)) (3.17.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 8)) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 8)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 8)) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 8)) (0.16.2)
# Requirement already satisfied: cryptography>=3.4 in /opt/conda/lib/python3.10/site-packages (from jwcrypto>=1.4.2->python-jwt>=2.0.1->pyrebase4->-r requirements.txt (line 12)) (41.0.7)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r requirements.txt (line 8)) (0.1.2)
# Requirement already satisfied: beautifulsoup4>=4.7.0 in /opt/conda/lib/python3.10/site-packages (from favicon->markdownlit>=0.0.5->streamlit-extras->-r requirements.txt (line 13)) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->streamlit-faker>=0.0.2->streamlit-extras->-r requirements.txt (line 13)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->streamlit-faker>=0.0.2->streamlit-extras->-r requirements.txt (line 13)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->streamlit-faker>=0.0.2->streamlit-extras->-r requirements.txt (line 13)) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->streamlit-faker>=0.0.2->streamlit-extras->-r requirements.txt (line 13)) (1.4.5)
# Collecting markdown (from markdownlit>=0.0.5->streamlit-extras->-r requirements.txt (line 13))
#   Downloading Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.7.0->favicon->markdownlit>=0.0.5->streamlit-extras->-r requirements.txt (line 13)) (2.5)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.10/site-packages (from cryptography>=3.4->jwcrypto>=1.4.2->python-jwt>=2.0.1->pyrebase4->-r requirements.txt (line 12)) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.4->jwcrypto>=1.4.2->python-jwt>=2.0.1->pyrebase4->-r requirements.txt (line 12)) (2.21)
# Downloading new_gfpgan-1.0.1-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 kB 3.3 MB/s eta 0:00:00
# Downloading my_basicsr-1.4.2-py3-none-any.whl (221 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.8/221.8 kB 17.0 MB/s eta 0:00:00
# Downloading facexlib-0.3.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 4.0 MB/s eta 0:00:00
# Downloading streamlit-1.36.0-py2.py3-none-any.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 96.8 MB/s eta 0:00:00:00:0100:01
# Downloading Pyrebase4-4.8.0-py3-none-any.whl (9.2 kB)
# Downloading streamlit_extras-0.4.3-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 4.4 MB/s eta 0:00:00
# Downloading streamlit_image_comparison-0.0.4-py3-none-any.whl (6.3 kB)
# Downloading streamlit_option_menu-0.3.13-py3-none-any.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.4/823.4 kB 41.0 MB/s eta 0:00:00
# Downloading pyngrok-7.1.6-py3-none-any.whl (22 kB)
# Downloading htbuilder-0.6.2-py3-none-any.whl (12 kB)
# Downloading markdownlit-0.0.7-py3-none-any.whl (15 kB)
# Downloading new_basicsr-1.0.0-py3-none-any.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.3/220.3 kB 15.7 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 95.6 MB/s eta 0:00:00:00:0100:01
# Downloading python_jwt-4.1.0-py2.py3-none-any.whl (7.1 kB)
# Downloading st_annotated_text-4.0.1-py3-none-any.whl (9.0 kB)
# Downloading st_theme-1.2.3-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.2/75.2 kB 5.8 MB/s eta 0:00:00
# Downloading streamlit_camera_input_live-0.2.0-py3-none-any.whl (6.6 kB)
# Downloading streamlit_card-1.0.2-py3-none-any.whl (680 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 680.8/680.8 kB 41.3 MB/s eta 0:00:00
# Downloading streamlit_embedcode-0.1.2-py3-none-any.whl (3.5 kB)
# Downloading streamlit_faker-0.0.3-py3-none-any.whl (14 kB)
# Downloading streamlit_image_coordinates-0.1.9-py3-none-any.whl (7.0 kB)
# Downloading streamlit_keyup-0.2.4-py3-none-any.whl (7.4 kB)
# Downloading streamlit_toggle_switch-1.0.2-py3-none-any.whl (635 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 635.4/635.4 kB 35.4 MB/s eta 0:00:00
# Downloading streamlit_vertical_slider-2.5.5-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 68.2 MB/s eta 0:00:00
# Downloading validators-0.29.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 2.6 MB/s eta 0:00:00
# Downloading watchdog-4.0.1-py3-none-manylinux2014_x86_64.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 6.3 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 22.0 MB/s eta 0:00:00
# Downloading tb_nightly-2.18.0a20240701-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 88.7 MB/s eta 0:00:00:00:01
# Downloading jwcrypto-1.5.6-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 kB 6.5 MB/s eta 0:00:00
# Downloading Faker-26.0.0-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 67.1 MB/s eta 0:00:00
# Downloading favicon-0.7.0-py2.py3-none-any.whl (5.9 kB)
# Downloading pymdown_extensions-10.8.1-py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.8/250.8 kB 17.4 MB/s eta 0:00:00
# Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.0 MB/s eta 0:00:00
# Building wheels for collected packages: gcloud, filterpy
#   Building wheel for gcloud (setup.py) ... done
#   Created wheel for gcloud: filename=gcloud-0.18.3-py3-none-any.whl size=602927 sha256=16d8119fcb4baebfb16fa89d0d7ef1775534ebd90f0a847e2031db98da088138
#   Stored in directory: /root/.cache/pip/wheels/7c/30/88/5017af921da3a33af785f0d0fd3e944b845bc62a445a2c2f69
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110458 sha256=7c8a6a6b9ac9744754dd33836ddcde6de46d382676419e9880e7d72463e45c9c
#   Stored in directory: /root/.cache/pip/wheels/0f/0c/ea/218f266af4ad626897562199fbbcba521b8497303200186102
# Successfully built gcloud filterpy
# Installing collected packages: lmdb, addict, watchdog, validators, pyngrok, markdown, htbuilder, tb-nightly, st-annotated-text, pymdown-extensions, pydeck, favicon, faker, jwcrypto, gcloud, filterpy, python-jwt, new-basicsr, MY-basicsr, facexlib, streamlit, pyrebase4, new-gfpgan, streamlit-vertical-slider, streamlit-toggle-switch, streamlit-option-menu, streamlit-keyup, streamlit-image-coordinates, streamlit-image-comparison, streamlit-embedcode, streamlit-card, streamlit-camera-input-live, st-theme, streamlit-faker, markdownlit, streamlit-extras
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.5.2
#     Uninstalling Markdown-3.5.2:
#       Successfully uninstalled Markdown-3.5.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.3.3 which is incompatible.
# Successfully installed MY-basicsr-1.4.2 addict-2.4.0 facexlib-0.3.0 faker-26.0.0 favicon-0.7.0 filterpy-1.4.5 gcloud-0.18.3 htbuilder-0.6.2 jwcrypto-1.5.6 lmdb-1.5.1 markdown-3.6 markdownlit-0.0.7 new-basicsr-1.0.0 new-gfpgan-1.0.1 pydeck-0.9.1 pymdown-extensions-10.8.1 pyngrok-7.1.6 pyrebase4-4.8.0 python-jwt-4.1.0 st-annotated-text-4.0.1 st-theme-1.2.3 streamlit-1.36.0 streamlit-camera-input-live-0.2.0 streamlit-card-1.0.2 streamlit-embedcode-0.1.2 streamlit-extras-0.4.3 streamlit-faker-0.0.3 streamlit-image-comparison-0.0.4 streamlit-image-coordinates-0.1.9 streamlit-keyup-0.2.4 streamlit-option-menu-0.3.13 streamlit-toggle-switch-1.0.2 streamlit-vertical-slider-2.5.5 tb-nightly-2.18.0a20240701 validators-0.29.0 watchdog-4.0.1

# %%
from pyngrok import ngrok
# Set up ngrok
ngrok.set_auth_token("2iGg2l1JGx7tznan8GQg940lB1h_Mnw7vfcyBc43SgDoSncv")

# Run Streamlit app in the background
get_ipython().system_raw('streamlit run main.py --server.port 8501 &')

# Expose the Streamlit app via ngrok
public_url = ngrok.connect(8501)
print(f'Public URL: {public_url}')
# Out:
# Public URL: NgrokTunnel: "https://5af5-34-83-199-253.ngrok-free.app" -> "http://localhost:8501"
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.19.2.2:8501
#   External URL: http://34.83.199.253:8501

# %% [markdown]
# !rm -rf EnhanceAI
